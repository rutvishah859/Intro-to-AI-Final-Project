# %%
#import libraries 
import requests
import folium
import os
import pandas as pd #to read and write spreadsheets
from csv import writer
import numpy as np
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA 
from sklearn.metrics import silhouette_score
import matplotlib.pyplot as plt #to make a graph
import collections
import json
import geopandas as gpd 

#get autharization code to access API
AUTHORIZATION = 'fsq389G1dW5rpyZXK8hM8aYJrVfIQulRs+pclsWRnaFed1I='
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\RUTVIS~1\AppData\Local\Temp/ipykernel_61020/24808689.py in <module>
#      12 import collections
#      13 import json
# ---> 14 import geopandas as gpd
#      15
#      16 #get autharization code to access API
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
headers = {
    "Accept": "application/json",
    "Authorization": AUTHORIZATION
}

df = pd.read_csv('Age_Vs_Crime.csv')
neighborhoods = df.columns[:]
school_count = [0]*140

for n in range(len(neighborhoods)):
    url = "https://api.foursquare.com/v3/places/search?query=school&near={}%2C%20Toronto".format(neighborhoods[n])
    response = requests.request("GET", url, headers=headers).json()
    
    names = ["elementary", "primary", "secondary", "high", "middle", "preschool"]
    
    for i in response["results"]:
        for j in i["categories"]:
            if any(name in j["name"].lower() for name in names):
                school_count[n] += 1
print(school_count)
# Out:
# [5, 5, 4, 2, 7, 2, 1, 1, 5, 4, 7, 6, 3, 1, 3, 3, 8, 2, 1, 0, 7, 0, 0, 7, 1, 7, 2, 0, 7, 7, 5, 2, 7, 7, 2, 7, 2, 1, 8, 3, 5, 0, 2, 1, 4, 7, 7, 0, 3, 5, 1, 2, 5, 2, 0, 1, 3, 7, 2, 7, 0, 2, 1, 2, 3, 6, 0, 7, 5, 4, 7, 3, 1, 5, 7, 3, 7, 0, 2, 0, 4, 7, 4, 1, 4, 7, 5, 2, 5, 0, 1, 0, 7, 5, 1, 3, 1, 7, 1, 5, 1, 7, 7, 3, 2, 1, 1, 7, 4, 2, 5, 4, 5, 3, 4, 7, 3, 7, 0, 1, 7, 7, 7, 0, 0, 4, 2, 7, 7, 7, 6, 2, 2, 7, 7, 7, 7, 7, 0, 7]

# %%
with open('Age_Vs_Crime.csv', 'a+', newline='') as write_obj:
        csv_writer = writer(write_obj)
        csv_writer.writerow(school_count)

# %%
df = pd.read_csv('Age_Vs_Crime.csv')
df = df.set_index([pd.Index(['Pop. of Ages 0-14', 'Crime Rate of B&E', 'Num. of Schools'])])
df = df.T
df['Pop. of Ages 0-14'] = df['Pop. of Ages 0-14'].astype(str).str.replace(',', '').astype(float)
df['Crime Rate of B&E'] = df['Crime Rate of B&E'].astype(str).str.replace(',', '').astype(float)
df['Num. of Schools'] = df['Num. of Schools'].astype(str).str.replace(',', '').astype(float)
df
# Out:
#                               Pop. of Ages 0-14  Crime Rate of B&E  \
# Agincourt North                          3840.0               49.0
# Agincourt South-Malvern West             3075.0               61.0
# Alderwood                                1760.0               26.0
# Annex                                    2360.0              123.0
# Banbury-Don Mills                        3605.0               57.0
# ...                                         ...                ...
# Wychwood                                 1860.0               29.0
# Yonge-Eglinton                           1800.0               19.0
# Yonge-St.Clair                           1210.0               12.0
# York University Heights                  4045.0               98.0
# Yorkdale-Glen Park                       1960.0               66.0
#
#                               Num. of Schools
# Agincourt North                           5.0
# Agincourt South-Malvern West              5.0
# ...

# %%
ssd = []
K = range(1, 50)
for k in K:
   cluster = KMeans(n_clusters=k).fit(df)
   ssd.append(cluster.inertia_)

# %%
plt.plot(K, ssd, 'bx-')
plt.xlabel('k')
plt.ylabel('sum of squared distances')
plt.title('Elbow Method for Optimal K')
# Out:
# Text(0.5, 1.0, 'Elbow Method for Optimal K')

# %%
sil = []
K_sil = range(2, 50)
for k in K_sil:
  cluster = KMeans(n_clusters=k).fit(df)
  labels = cluster.labels_
  sil.append(silhouette_score(df, labels, metric='euclidean'))

# %%
plt.plot(K_sil, sil, 'bx-')
plt.xlabel('k')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Method for Optimal K')
# Out:
# Text(0.5, 1.0, 'Silhouette Method for Optimal K')

# %% [markdown]
# Pick k = 5 (optimal k according to elbow method). There is also a peak at k = 5, as observed with the silhouette method.

# %%
#number of clusters
k = 5
#run K-Means clustering algorithm
cluster = KMeans(n_clusters=k).fit(df)
#prints the counts of neighbourhoods assigned to diff. clusters
print(collections.Counter(cluster.labels_))
# Out:
# Counter({1: 62, 0: 38, 3: 28, 2: 8, 4: 4})

# %%
#labels 
labels = cluster.labels_
results = pd.DataFrame([df.index, labels]).T
results
# Out:
#                                 0  1
# 0                 Agincourt North  3
# 1    Agincourt South-Malvern West  0
# 2                       Alderwood  1
# 3                           Annex  0
# 4               Banbury-Don Mills  3
# ..                            ... ..
# 135                      Wychwood  1
# 136                Yonge-Eglinton  1
# 137                Yonge-St.Clair  1
# 138       York University Heights  3
# 139            Yorkdale-Glen Park  1
#
# [140 rows x 2 columns]

# %%
#joins the table with all the headings together
df['Score'] = df.apply(lambda row: row['Pop. of Ages 0-14']/row['Crime Rate of B&E']*row['Num. of Schools'], axis=1)
df['Cluster'] = results[1].values
df
# Out:
#                               Pop. of Ages 0-14  Crime Rate of B&E  \
# Agincourt North                          3840.0               49.0
# Agincourt South-Malvern West             3075.0               61.0
# Alderwood                                1760.0               26.0
# Annex                                    2360.0              123.0
# Banbury-Don Mills                        3605.0               57.0
# ...                                         ...                ...
# Wychwood                                 1860.0               29.0
# Yonge-Eglinton                           1800.0               19.0
# Yonge-St.Clair                           1210.0               12.0
# York University Heights                  4045.0               98.0
# Yorkdale-Glen Park                       1960.0               66.0
#
#                               Num. of Schools       Score Cluster
# Agincourt North                           5.0  391.836735       3
# ...

# %%
clusters = df.groupby('Cluster')
print(clusters['Score'].mean())
clusters = clusters['Score'].mean()
# Out:
# Cluster
# 0    319.327294
# 1    247.745093
# 2    903.085230
# 3    264.266136
# 4    603.731439
# Name: Score, dtype: float64

# %% [markdown]
# The best cluster for our goal is Cluster 4 with the highest mean score, followed by cluster 3, 2, 1 and 0 (assending order)

# %%
m = folium.Map(location=[43.6532, -79.3832], zoom_start=12)
geojson_layer = folium.GeoJson(json.load(open('Neighbourhoods.geojson')),
                               name='geojson').add_to(m)
m.fit_bounds(geojson_layer.get_bounds())

# %%
geoJSON = gpd.read_file('Neighbourhoods.geojson')
geoJSON
# Out:
#      AREA_ATTR_ID                     AREA_DESC  AREA_ID AREA_LONG_CODE  \
# 0        26005521                Casa Loma (96)  2480141            096
# 1        26005520                    Annex (95)  2480140            095
# 2        26005519      Caledonia-Fairbank (109)  2480139            109
# 3        26005444        Woodbine Corridor (64)  2480064            064
# 4        26005443     Lawrence Park South (103)  2480063            103
# ..            ...                           ...      ...            ...
# 135      26005522             Dorset Park (126)  2480142            126
# 136      26005448  Centennial Scarborough (133)  2480068            133
# 137      26005447               Humbermede (22)  2480067            022
# 138      26005446          Willowdale West (37)  2480066            037
# 139      26005445          Willowdale East (51)  2480065            051
#
#                         AREA_NAME AREA_SHORT_CODE  \
# 0                  Casa Loma (96)             096
# ...

# %%
geo_df = geoJSON
geo_df = geo_df.sort_values(by=['AREA_NAME'], ascending=True)
geo_df.reset_index(drop=True, inplace=True)
results.reset_index(drop=True, inplace=True)
geo_df = pd.concat([geo_df, results], axis=1) 
geo_df.rename(columns = {0:'Neighbourhood', 1:'Cluster'}, inplace = True)
geo_df = geo_df.astype({'Cluster': 'int'})
geo_df
# Out:
#      AREA_ATTR_ID                           AREA_DESC  AREA_ID AREA_LONG_CODE  \
# 0        26005558               Agincourt North (129)  2480178            129
# 1        26005424  Agincourt South-Malvern West (128)  2480044            128
# 2        26005425                      Alderwood (20)  2480045            020
# 3        26005520                          Annex (95)  2480140            095
# 4        26005427              Banbury-Don Mills (42)  2480047            042
# ..            ...                                 ...      ...            ...
# 135      26005524                       Wychwood (94)  2480144            094
# 136      26005437                Yonge-Eglinton (100)  2480057            100
# 137      26005523                 Yonge-St.Clair (97)  2480143            097
# 138      26005526        York University Heights (27)  2480146            027
# 139      26005485             Yorkdale-Glen Park (31)  2480105            031
#
# ...

# %%
folium.Choropleth(
    geo_data=geo_df,
    name='choropleth',
    data=geo_df,
    columns=['Neighbourhood', 'Cluster'],
    key_on='feature.properties.Neighbourhood',
    fill_color='YlGnBu',
    fill_opacity=0.7,
    line_opacity=0.2,
    legend_name="Cluster",
    Highlight= True
).add_to(m)
m
# import branca.colormap as cmp
# colormap = cmp.linear.YlGnBu_09.scale(0, 4)
# colormap = colormap.to_step(index=[0, 1, 2, 3, 4])
# colormap.caption = 'Cluster'
# colormap.add_to(m)
# m
# step = cmp.StepColormap(
#  ['yellow', 'green', 'purple', 'blue'],
#  vmin=0, vmax=4,
#  index=[0, 1, 2, 3],  #for change in the colors, not used fr linear
#  caption='Cluster'    #Caption for Color scale or Legend
# )
# step.to_linear()
# folium.GeoJson(
#     geo_df,
#     style_function=lambda feature: {
#         'fillColor': step(geo_df[feature['id']]),
#         'color': 'black',       #border color for the color fills
#         'weight': 1,            #how thick the border has to be
#         'dashArray': '5, 3'  #dashed lines length,space between them
#     }
# ).add_to(m)
# step.add_to(m)     #adds colorscale or legend
# m
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/IPython/core/formatters.py in __call__(self, obj)
#     336             method = get_real_method(obj, self.print_method)
#     337             if method is not None:
# --> 338                 return method()
#     339             return None
#     340         else:
#
# /usr/local/lib/python3.7/dist-packages/folium/folium.py in _repr_html_(self, **kwargs)
#     284             self._parent = None
#     285         else:
# --> 286             out = self._parent._repr_html_(**kwargs)
#     287         return out
#     288
#
# /usr/local/lib/python3.7/dist-packages/branca/element.py in _repr_html_(self, **kwargs)
#     329
#     330         """
# --> 331         html = urllib.parse.quote(self.render(**kwargs))
#     332         onload = (
#     333             'this.contentDocument.open();'
#
# ...

# %%
# all the neighbourhoods in cluster 1
df[df['Cluster'] == 1]
# Out:
#                          Pop. of Ages 0-14  Crime Rate of B&E  \
# Alderwood                           1760.0               26.0
# Bay Street Corridor                 1695.0              120.0
# Bayview Woods-Steeles               1515.0               33.0
# Beechborough-Greenbrook             1120.0               11.0
# Blake-Jones                         1405.0               23.0
# ...                                    ...                ...
# Woodbine-Lumsden                    1165.0               12.0
# Wychwood                            1860.0               29.0
# Yonge-Eglinton                      1800.0               19.0
# Yonge-St.Clair                      1210.0               12.0
# Yorkdale-Glen Park                  1960.0               66.0
#
#                          Num. of Schools       Score Cluster
# Alderwood                            4.0  270.769231       1
# Bay Street Corridor                  1.0   14.125000       1
# ...

# %%
# all the neighbourhoods in cluster 2
df[df['Cluster'] == 2]
# Out:
#                             Pop. of Ages 0-14  Crime Rate of B&E  \
# Downsview-Roding-CFB                   5725.0               52.0
# Glenfield-Jane Heights                 5790.0               30.0
# Islington-City Centre West             5820.0              105.0
# L'Amoreaux                             6120.0                9.0
# Parkwoods-Donalda                      5840.0               46.0
# Thorncliffe Park                       5600.0               24.0
# West Humber-Clairville                 5060.0              131.0
# Willowdale East                        5920.0               78.0
#
#                             Num. of Schools        Score Cluster
# Downsview-Roding-CFB                    7.0   770.673077       2
# Glenfield-Jane Heights                  7.0  1351.000000       2
# Islington-City Centre West              2.0   110.857143       2
# L'Amoreaux                              6.0  4080.000000       2
# ...

# %%
# all the neighbourhoods in cluster 3
df[df['Cluster'] == 3]
# Out:
#                                      Pop. of Ages 0-14  Crime Rate of B&E  \
# Agincourt North                                 3840.0               49.0
# Banbury-Don Mills                               3605.0               57.0
# Bedford Park-Nortown                            4555.0               97.0
# Bendale                                         4550.0               57.0
# Black Creek                                     4600.0               27.0
# Clairlea-Birchmount                             4565.0               86.0
# Don Valley Village                              4065.0               65.0
# Dorset Park                                     4250.0               70.0
# Dovercourt-Wallace Emerson-Junction             4480.0               78.0
# East End-Danforth                               3735.0               77.0
# Eglinton East                                   4180.0               65.0
# Englemount-Lawrence                             4805.0               59.0
# ...

# %%
# all the neighbourhoods in cluster 4
df[df['Cluster'] == 4]
# Out:
#                                    Pop. of Ages 0-14  Crime Rate of B&E  \
# Malvern                                       7910.0               65.0
# Mount Olive-Silverstone-Jamestown             7090.0               34.0
# Rouge                                         7960.0               75.0
# Woburn                                        9625.0               80.0
#
#                                    Num. of Schools        Score Cluster
# Malvern                                        5.0   608.461538       4
# Mount Olive-Silverstone-Jamestown              7.0  1459.705882       4
# Rouge                                          1.0   106.133333       4
# Woburn                                         2.0   240.625000       4
